# %% [markdown]
# # Building your own algorithm container

# %%
# !cat container/Dockerfile
# Out:
# # Build an image that can do training and inference in SageMaker
# # This is a Python 3 image that uses the nginx, gunicorn, flask stack
# # for serving inferences in a stable way.
#
# FROM python:3.10-slim-buster
#
# MAINTAINER Amazon AI <sage-learner@amazon.com>
#
#
# RUN apt-get -y update && apt-get install -y --no-install-recommends \
#          wget \
#          python3-pip \
#          python3-setuptools \
#          nginx \
#          ca-certificates \
#     && rm -rf /var/lib/apt/lists/*
#
# RUN ln -s /usr/bin/python3 /usr/bin/python
# RUN ln -s /usr/bin/pip3 /usr/bin/pip
#
# # Here we get all python packages.
# # There's substantial overlap between scipy and numpy that we eliminate by
# # linking them together. Likewise, pip leaves the install caches populated which uses
# # a significant amount of space. These optimizations save a fair amount of space in the
# # image, which reduces start up time.
# RUN pip --no-cache-dir install numpy==1.26.4 scipy==1.12.0 scikit-learn==1.4.1.post1 pandas==1.5.3 xlsxwriter==3.2.0 openpyxl==3.1.2 boto3==1.34.69 flask gunicorn
# RUN pip install spacy==3.7.4
#
# # Set some environment variables. PYTHONUNBUFFERED keeps Python from buffering our standard
# # output stream, which means that logs can be delivered to the user quickly. PYTHONDONTWRITEBYTECODE
# # keeps Python from writing the .pyc files which are unnecessary in this case. We also update
# # PATH so that the train and serve programs are found when the container is invoked.
#
# ENV PYTHONUNBUFFERED=TRUE
# ENV PYTHONDONTWRITEBYTECODE=TRUE
# ENV PATH="/opt/program:${PATH}"
#
# # Set up the program in the image
# COPY decision_trees /opt/program
# WORKDIR /opt/program

# %%
# %%sh
#
# # The name of our algorithm
# algorithm_name=sagemaker-custom-spacy-new-training-job
#
# cd container
#
# chmod +x decision_trees/train
# chmod +x decision_trees/serve
#
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# aws ecr get-login-password --region ${region}|docker login --username AWS --password-stdin ${fullname}
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build -t ${algorithm_name} .
# docker tag ${algorithm_name} ${fullname}
#
# docker push ${fullname}
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
# Login Succeeded
# Sending build context to Docker daemon  57.34kB
# Step 1/12 : FROM python:3.10-slim-buster
#  ---> 93b9055430ce
# Step 2/12 : MAINTAINER Amazon AI <sage-learner@amazon.com>
#  ---> Using cache
#  ---> 5a15fbf1c972
# Step 3/12 : RUN apt-get -y update && apt-get install -y --no-install-recommends          wget          python3-pip          python3-setuptools          nginx          ca-certificates     && rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> bca9c2d558f4
# Step 4/12 : RUN ln -s /usr/bin/python3 /usr/bin/python
#  ---> Using cache
#  ---> c3d8a1f7953b
# Step 5/12 : RUN ln -s /usr/bin/pip3 /usr/bin/pip
#  ---> Using cache
#  ---> 8f9d358ac77d
# Step 6/12 : RUN pip --no-cache-dir install numpy==1.26.4 scipy==1.12.0 scikit-learn==1.4.1.post1 pandas==1.5.3 xlsxwriter==3.2.0 openpyxl==3.1.2 boto3==1.34.69 flask gunicorn
#  ---> Using cache
#  ---> f436a4bf1a76
# Step 7/12 : RUN pip install spacy==3.7.4
#  ---> Using cache
#  ---> 641b8738a939
# Step 8/12 : ENV PYTHONUNBUFFERED=TRUE
#  ---> Using cache
#  ---> d292c1674736
# Step 9/12 : ENV PYTHONDONTWRITEBYTECODE=TRUE
#  ---> Using cache
#  ---> 625bd6be23ba
# Step 10/12 : ENV PATH="/opt/program:${PATH}"
#  ---> Using cache
#  ---> 9af32cc0daca
# Step 11/12 : COPY decision_trees /opt/program
#  ---> 96aece8d8f7d
# Step 12/12 : WORKDIR /opt/program
#  ---> Running in 5a542a6afda5
# Removing intermediate container 5a542a6afda5
#  ---> 22f0793a4418
# Successfully built 22f0793a4418
# Successfully tagged sagemaker-custom-spacy-new-training-job:latest
# The push refers to repository [661082688832.dkr.ecr.eu-west-2.amazonaws.com/sagemaker-custom-spacy-new-training-job]
# 505e2250cc4c: Preparing
# 68e2cf6e5465: Preparing
# 3663ebf3854c: Preparing
# 16d1da46eba5: Preparing
# 25fab66e0f96: Preparing
# 21167557fa70: Preparing
# c5321f7f53ff: Preparing
# df6c1b185b95: Preparing
# b23fedba7dbd: Preparing
# ae2d55769c5e: Preparing
# e2ef8a51359d: Preparing
# 21167557fa70: Waiting
# c5321f7f53ff: Waiting
# df6c1b185b95: Waiting
# b23fedba7dbd: Waiting
# ae2d55769c5e: Waiting
# e2ef8a51359d: Waiting
# 25fab66e0f96: Layer already exists
# 3663ebf3854c: Layer already exists
# 16d1da46eba5: Layer already exists
# 68e2cf6e5465: Layer already exists
# b23fedba7dbd: Layer already exists
# c5321f7f53ff: Layer already exists
# 21167557fa70: Layer already exists
# df6c1b185b95: Layer already exists
# ae2d55769c5e: Layer already exists
# e2ef8a51359d: Layer already exists
# 505e2250cc4c: Pushed
# latest: digest: sha256:ea641a892eff5f9d76e492fb11139ead7ae4273580e502e7723c8a4e8532cce9 size: 2630

# %% [markdown]
# ## Part 2: Using your Algorithm in Amazon SageMaker
#
# Once you have your container packaged, you can use it to train models and use the model for hosting or batch transforms. Let's do that with the algorithm we made above.
#
# ## Set up the environment
#
# Here we specify a bucket to use and the role that will be used for working with SageMaker.

# %%
# S3 prefix
prefix = "DEMO-Spacy-byoc"

# Define IAM role
import boto3
import re

import os
import numpy as np
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# ## Create the session
#
# The session remembers our connection parameters to SageMaker. We'll use it to perform all of our SageMaker operations.

# %%
import sagemaker as sage
from time import gmtime, strftime

sess = sage.Session()

# %% [markdown]
# ## Upload the data for training
#
# When training large models with huge amounts of data, you'll typically use big data tools, like Amazon Athena, AWS Glue, or Amazon EMR, to create your data in S3. For the purposes of this example, we're using some the classic [Iris dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set), which we have included.
#
# We can use use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
WORK_DIRECTORY = "data"

data_location = sess.upload_data(WORK_DIRECTORY, key_prefix=prefix)

# %%
data_location
# Out:
# 's3://sagemaker-eu-west-2-661082688832/DEMO-Spacy-byoc'

# %% [markdown]
# ## Create an estimator and fit the model
#
# In order to use SageMaker to fit our algorithm, we'll create an `Estimator` that defines how to use the container to train. This includes the configuration we need to invoke SageMaker training:
#
# * The __container name__. This is constructed as in the shell commands above.
# * The __role__. As defined above.
# * The __instance count__ which is the number of machines to use for training.
# * The __instance type__ which is the type of machine to use for training.
# * The __output path__ determines where the model artifact will be written.
# * The __session__ is the SageMaker session object that we defined above.
#
# Then we use fit() on the estimator to train against the data that we uploaded above.

# %%
account = sess.boto_session.client("sts").get_caller_identity()["Account"]
region = sess.boto_session.region_name
image = "{}.dkr.ecr.{}.amazonaws.com/sagemaker-custom-spacy-new-training-job:latest".format(account, region)

tree = sage.estimator.Estimator(
    image,
    role,
    1,
    "ml.c4.2xlarge",
    output_path="s3://{}/output".format(sess.default_bucket()),
    sagemaker_session=sess,
)

tree.fit(data_location)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-custom-spacy-new-training-job-2024-04-05-13-13-31-316
# 2024-04-05 13:13:31 Starting - Starting the training job...
# 2024-04-05 13:13:51 Starting - Preparing the instances for training......
# 2024-04-05 13:15:01 Downloading - Downloading the training image
# 2024-04-05 13:15:01 Training - Training image download completed. Training in progress...Starting the training.
# trainning Parameeter:------ {}
# #015  0%|          | 0/608 [00:00<?, ?it/s]#015100%|██████████| 608/608 [00:00<00:00, 18766.05it/s]
# *********** Starting*****************
# 22nd april 2020
# 597
# 611
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 december 2021
# 415
# 429
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 january 2021
# 381
# 394
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st september 2021
# 97
# 114
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st april 2020
# 633
# 646
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 24 august 2021
# 682
# 695
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30 june 2021
# 330
# 341
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 march 2020
# 601
# 613
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 31st january 2020
# 517
# 533
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 25th april 2020
# 468
# 482
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30th october 2021
# 46
# 62
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 15th november 2020
# 78
# 95
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30 june 2020
# 191
# 202
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 20 january 2020
# 290
# 304
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st july 2020
# 297
# 309
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 15th may 2020
# 236
# 248
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 4th june 2020
# 235
# 247
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 march 2021
# 547
# 558
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 5th august 2020
# 407
# 421
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 july 2021
# 321
# 332
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 april 2021
# 496
# 508
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st december 2021
# 144
# 160
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 january 2020
# 620
# 634
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30th december 2021 at 12:01pm
# 300
# 328
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 19 march 2020
# 267
# 279
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 15 may 2021
# 257
# 267
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st january 2020
# 133
# 148
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 december 2020
# 401
# 416
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 16 july 2021
# 325
# 336
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 29 december 2020
# 73
# 88
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 31st january 2020
# 502
# 518
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 19 november 2020
# 521
# 536
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 21st november 2020
# 1297
# 1314
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 october 2020
# 499
# 512
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 21 november 2021
# 1067
# 1082
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 31st december 2021
# 1043
# 1060
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 june, 2020
# 477
# 488
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 november 2021
# 782
# 797
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 november 2021
# 755
# 770
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 may 2021
# 468
# 477
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 20th december 2020
# 313
# 330
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 10 november 2020
# 227
# 242
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30th september 2021
# 115
# 133
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 june 2020
# 162
# 173
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st november 2020
# 170
# 186
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 8 december 2021
# 368
# 382
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30 november 2020
# 434
# 449
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 8th december 2020
# 357
# 373
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 march 2020
# 121
# 133
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 16 july 2020
# 325
# 336
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 july 2020
# 255
# 265
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 november 2020
# 190
# 204
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01-01-2021
# 618
# 627
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30 september 2020
# 191
# 207
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 31 december 2021
# 974
# 989
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 31 march 2020
# 205
# 217
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30 june 2021
# 253
# 264
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 december 2021
# 784
# 799
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 june 2020
# 41
# 51
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st june 2021
# 120
# 132
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st january 2020
# 119
# 134
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st may 2020
# 385
# 396
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st december 2020
# 280
# 296
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 6th march 2020
# 124
# 137
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 01 may 2021
# 333
# 343
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30th april 2020
# 306
# 320
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 31 october 2020
# 569
# 583
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 26th june 2021
# 128
# 141
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 30 june 2021
# 309
# 320
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1 june 2020
# 41
# 51
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 27 july 2021
# 323
# 334
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 29th july 2020
# 654
# 667
# IncepDate
# *********** Ending*****************
# *********** Starting*****************
# 1st september 2021
# 343
# 360
# IncepDate
# *********** Ending*****************
# #015  0%|          | 0/50 [00:00<?, ?it/s]#015100%|██████████| 50/50 [00:00<00:00, 702.97it/s]
# #033✔ Auto-filled config with all values#033
# #033✔ Saved config#033
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy
# #033✔ Created output directory: output#033
# #033ℹ Saving to output directory: output#033
# #033ℹ Using CPU#033
# #033
# =========================== Initializing pipeline ===========================#033
# #033✔ Initialized pipeline#033
# #033
# ============================= Training pipeline =============================#033
# #033ℹ Pipeline: ['tok2vec', 'ner']#033
# #033ℹ Initial learn rate: 0.001#033
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     91.50    2.74    1.59   10.00    0.03
#   2     200        918.79   1966.97   89.52   85.45   94.00    0.90
#   4     400         13.25     27.90   92.16   90.38   94.00    0.92
#   6     600         85.12     30.17   93.33   89.09   98.00    0.93
#   8     800         14.61     19.09   89.91   83.05   98.00    0.90
#  10    1000         22.47     12.56   89.72   84.21   96.00    0.90
#  12    1200          8.86      7.82   90.57   85.71   96.00    0.91
#  14    1400         10.20      7.74   91.43   87.27   96.00    0.91
#  16    1600          0.13      0.17   92.45   87.50   98.00    0.92
#  18    1800          0.00      0.00   91.43   87.27   96.00    0.91
#  20    2000          0.00      0.00   91.43   87.27   96.00    0.91
#  22    2200          0.00      0.00   91.43   87.27   96.00    0.91
# #033✔ Saved pipeline to output directory#033
# output/model-last
# Training complete.
#
# 2024-04-05 13:17:33 Uploading - Uploading generated training model
# 2024-04-05 13:17:33 Completed - Training job completed
# Training seconds: 171
# Billable seconds: 171

# %%
data_location
# Out:
# 's3://sagemaker-eu-west-2-661082688832/DEMO-Spacy-byoc'
